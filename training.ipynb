# %%
import os
actors = os.listdir('data')

# %%
os.listdir(os.path.join('data',actors[0]))

# %%
filenames=[]
for actor in actors:
    for file in os.listdir(os.path.join('data',actor)):
        filenames.append(os.path.join('data',actor,file))

# %%
filenames[0]
# Out:
# 'data/Aamir_Khan/Aamir.100.jpg'

# %%
import pickle

pickle.dump(filenames, open('filenames.pkl','wb'))

# %%
from tensorflow.keras.preprocessing import image
from keras_vggface.utils import preprocess_input
from keras_vggface.vggface import VGGFace
# from deepface.model.facial_recognition import VGGFace
import numpy as np
import pickle
import tensorflow as tf
import tqdm
# Out:
# 2025-11-27 08:10:20.282662: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
filename = pickle.load(open('filenames.pkl','rb'))

# %%
model = VGGFace(model='resnet50', include_top=False, input_shape=(224,224,3), pooling='avg')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764231029.066965    7282 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2242 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
def feature_extractor(img_path, model):
    img = image.load_img(img_path, target_size= (224,224))
    img_arr = image.img_to_array(img)
    expand_img = np.expand_dims(img_arr, axis=0)
    process_img = preprocess_input(expand_img)
    result = model.predict(process_img)
    flat_pred = result.flatten()
    return flat_pred

# %%
features = []
for file in tqdm(filenames):
    features.append(feature_extractor(file, model))

pickle.dump(features, open('features.pkl','wb'))

# %%
# %run feature_extractor.py
# Out:
# 2025-11-27 08:34:16.045638: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764232462.275124    8099 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2242 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
#   0%|                                                                                          | 0/8664 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /mnt/e/AI-ML course/bollywood_celeb_predictor/feature_extractor.py:25
# ...

# %%
exit()

# %%
# from deepface import DeepFace
from tensorflow.keras.layers import GlobalMaxPool2D

# %%
from deepface import DeepFace
# Out:
# 2025-11-27 10:23:42.352238: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
result_emb = DeepFace.represent(img_path='data/Aamir_Khan/Aamir.100.jpg', model_name = 'VGG-Face')
# Out:
# 2025-11-27 10:24:00.402717: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764239040.402829    9123 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2242 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# 25-11-27 10:24:01 - 🔗 vgg_face_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5 to /home/huzefa_m/.deepface/weights/vgg_face_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: /home/huzefa_m/.deepface/weights/vgg_face_weights.h5
# ...

# %%
import numpy as np
result_arr = np.array(result_emb[0]['embedding'])

# %%
layer = GlobalMaxPool2D()(expand_result)

# %%
layer.shape
# Out:
# TensorShape([2, 1024])

# %%
layer_numpy = layer.numpy()

# %%
layer_numpy
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.03405961, 0.        ,
#         0.00798661],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ]], shape=(2, 1024), dtype=float32)

# %%
flat_layer = layer_numpy.flatten()

# %%
flat_layer.shape
# Out:
# (2048,)

# %%
from tensorflow.keras.layers import Flatten

flat_layer = Flatten()(layer)

# %%
flat_layer.shape
# Out:
# TensorShape([2, 1024])

# %%
# h,w,c = 7,7,256
result_arr_4d = result_arr.reshape(2,2,1024)

# %%
expand_result = np.expand_dims(result_arr_4d,1)

# %%
expand_result.shape
# Out:
# (2, 1, 2, 1024)

# %%
ex_expand_result = np.expand_dims(expand_result,0)

# %%
ex_expand_result.shape
# Out:
# (1, 1, 8, 8, 64)

# %%
e_ex_expand_result = np.expand_dims(ex_expand_result,1)

# %%
e_ex_expand_result.shape
# Out:
# (4096, 1, 1, 1)

# %%
layer.shape
# Out:
# TensorShape([1, 64])

# %%
layer1 = GlobalMaxPool2D()(layer)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 layer1 = GlobalMaxPool2D()(layer)
#
# File ~/miniconda3/envs/bhai/lib/python3.12/site-packages/tf_keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/miniconda3/envs/bhai/lib/python3.12/site-packages/tf_keras/src/engine/input_spec.py:235, in assert_input_compatibility(input_spec, inputs, layer_name)
#     233     ndim = shape.rank
#     234     if ndim != spec.ndim:
# --> 235         raise ValueError(
# ...

# %%
def extract_features(img_paths):
    deepfaced = DeepFace.represent(img_path=img_paths, model_name='VGG-Face')
    into_arr = np.array(deepfaced[0]['embedding'])
    into_arr_4d = into_arr.reshape(2,2,1024)
    ex_into_arr_4d = np.expand_dims(into_arr_4d,1)
    layer = GlobalMaxPool2D()(ex_into_arr_4d)
    layer_numpy = layer.numpy()
    flat_layer = layer_numpy.flatten()
    norm_layer = flat_layer/norm(flat_layer)
    return norm_layer

# %%
from numpy.linalg import norm
feature.append(extract_features('data/Aamir_Khan/Aamir.100.jpg'))

# %%
feature = []

# %%
feature.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 feature.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
import pickle

embed = pickle.load(open('/mnt/e/AI-ML course/Fashion Recommender System/embeddings.pkl', 'rb'))

# %%
embed.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 embed.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
filenames = pickle.load(open('filenames.pkl', 'rb'))

# %%
pickle.dump(feature, open('features.pkl', 'wb')

# %%
# %run feature_extractor1.py
# Out:
# 2025-11-27 13:01:26.621603: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#   0%|                                                                                          | 0/8664 [00:00<?, ?it/s]2025-11-27 13:01:51.051077: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764248511.051171   11860 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2242 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# ...

# %%
exit()

# %%
# %run test.py
# Out:
# 2025-11-27 14:31:35.489919: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-27 14:32:26.964286: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764253946.964487   12807 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2242 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# ...

# %%
exit()

# %% [markdown]
# # Now Testing

# %%
import pickle
import os
import cv2
from mtcnn import MTCNN
import numpy as np
import tensorflow as tf
from sklearn.metrics.pairwise import cosine_similarity
from deepface import DeepFace
from tensorflow.keras.layers import GlobalMaxPool2D
from numpy.linalg import norm
from tensorflow.keras.preprocessing import image

# %%
feature_list = pickle.load(open('features.pkl', 'rb'))
filenames = pickle.load(open('filenames.pkl', 'rb'))

# %%
def extract_features(img_paths):
    deepfaced = DeepFace.represent(img_path=img_paths, model_name='VGG-Face', enforce_detection=False)
    into_arr = np.array(deepfaced[0]['embedding'])
    into_arr_4d = into_arr.reshape(2,2,1024)
    ex_into_arr_4d = np.expand_dims(into_arr_4d,1)
    layer = GlobalMaxPool2D()(ex_into_arr_4d)
    layer_numpy = layer.numpy()
    flat_layer = layer_numpy.flatten()
    norm_layer = flat_layer/norm(flat_layer)
    return norm_layer

# %%
img_loc = 'sample/ranbir_kapoor_dup.jpg'
sample_img = extract_features(img_loc)
print(sample_img)
# Out:
# [0.         0.0004206  0.         ... 0.         0.         0.01932297]

# %%
sample_img.shape
# Out:
# (2048,)

# %%
type(sample_img)
# Out:
# numpy.ndarray

# %%
sample_img.reshape(1,-1)
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.00723872, 0.        ,
#         0.        ]], shape=(1, 2048), dtype=float32)

# %%
feature_list[0]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], shape=(2048,), dtype=float32)

# %%
s1 = cosine_similarity(sample_img.reshape(1,-1),feature_list[0].reshape(1,-1))[0][0]

# %%
s2 = cosine_similarity(sample_img.reshape(1,-1),feature_list[1].reshape(1,-1))[0][0]

# %%
similarity.append(s1)

# %%
similarity
# Out:
# []

# %%
similarity.append(s2)

# %%
similarity.sort
# Out:
# <function list.sort(*, key=None, reverse=False)>

# %%
similarity =[]

# %%
for i, arr in enumerate(feature_list):
    simi = cosine_similarity(sample_img.reshape(1,-1),arr.reshape(1,-1))[0][0]
    similarity.append(simi)

# %%
similarity1 = similarity

# %%
index_of_max = similarity.index(max(similarity))

# %%
filenames[index_of_max]
# Out:
# 'data/Anushka_Shetty/Anushka_Shetty.245.jpg'

# %%
float(f"{(float(max(similarity))*100):.2f}")
# Out:
# 56.9

# %%
index_pos  = sorted(list(enumerate(similarity1)),reverse=True, key=lambda x:x[1])[0][0]

# %%
index_pos
# Out:
# 1458

# %%
index_of_max
# Out:
# 1458

# %%
str = filenames[index_of_max]

# %%
predicted_path.split('/')[1].replace('_',' ')
# Out:
# 'Anushka Shetty'

# %% [markdown]
# # Detect Face

# %%
detector = MTCNN()
img_loc = 'sample/Ruquaiyah.jpeg'

# %%
to_face_img = cv2.imread(img_loc)

# %%
to_face_img.shape
# Out:
# (1280, 853, 3)

# %%
# 1.
for i in range(10):
    if to_face_img.shape[0]>800:
        to_face_img = cv2.resize(to_face_img, (int(to_face_img.shape[0]/2),to_face_img.shape[1]))
        if to_face_img.shape[1]>800:
            to_face_img = cv2.resize(to_face_img, (to_face_img.shape[0],int(to_face_img.shape[1]>800/2)))
    else:
        break

# %%
to_face_img.shape
# Out:
# (640, 426, 3)

# %%
# resizing of uploaded image
# 2.
for i in range(10):
    if to_face_img.shape[0]>800 and to_face_img.shape[1]>800:
        to_face_img = cv2.resize(to_face_img, (int((to_face_img.shape[1])/2),int((to_face_img.shape[0])/2)))
    else: 
        break

# %%
to_face_img.shape
# Out:
# (640, 426, 3)

# %%
result = detector.detect_faces(to_face_img)
result
# Out:
# [{'box': [162, 98, 117, 150],
#   'confidence': np.float64(0.9984492063522339),
#   'keypoints': {'nose': [np.int64(218), np.int64(187)],
#    'mouth_right': [np.int64(245), np.int64(213)],
#    'right_eye': [np.int64(249), np.int64(156)],
#    'left_eye': [np.int64(191), np.int64(156)],
#    'mouth_left': [np.int64(192), np.int64(211)]}}]

# %%
x,y,width,height = result[0]['box']

# %%
face = to_face_img[y:y+height,x:x+width]

# %%
cv2.imshow('output',face)
cv2.waitKey(0)
# Out:
# 233

# %% [markdown]
# ## Extract features

# %%
face1 = cv2.resize(face, (224,224))

# %%
type(face1)
# Out:
# numpy.ndarray

# %%
# img_loc = 'sample/ranbir_kapoor_dup.jpg'
sample_img = extract_features(face1)
print(sample_img)
# Out:
# [0.        0.        0.0944097 ... 0.        0.        0.       ]

# %%
# %%time
# %run test.py
# Out:
# 56.9%
# CPU times: user 5.41 s, sys: 0 ns, total: 5.41 s
# Wall time: 10 s

# %%
# !pip install bing-image-downloader

# %%
# %run untitled.py
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /mnt/e/AI-ML course/bollywood_celeb_predictor/untitled.py:11
#       9 urls = ['https://www.instagram.com/amandacerny']
#      10 save_folder = './downloaded'
# ---> 11 web_image_downloader.download_images(urls, save_folder)
#
# AttributeError: module 'web_image_downloader' has no attribute 'download_images'

# %%
# !pip uninstall web_image_downloader -y
# Out:
# Found existing installation: web-image-downloader 1.0
# Uninstalling web-image-downloader-1.0:
#   Successfully uninstalled web-image-downloader-1.0

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 y
#
# NameError: name 'y' is not defined
